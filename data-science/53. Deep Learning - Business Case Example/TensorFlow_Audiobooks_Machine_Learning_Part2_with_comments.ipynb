# %% [markdown]
# # Practical example. Audiobooks

# %% [markdown]
# ## Problem
#
# You are given data from an Audiobook app. Logically, it relates only to the audio versions of books. Each customer in the database has made a purchase at least once, that's why he/she is in the database. We want to create a machine learning algorithm based on our available data that can predict if a customer will buy again from the Audiobook company.
#
# The main idea is that if a customer has a low probability of coming back, there is no reason to spend any money on advertizing to him/her. If we can focus our efforts ONLY on customers that are likely to convert again, we can make great savings. Moreover, this model can identify the most important metrics for a customer to come back again. Identifying new customers creates value and growth opportunities.
#
# You have a .csv summarizing the data. There are several variables: Customer ID, Book length in mins_avg (average of all purchases), Book length in minutes_sum (sum of all purchases), Price Paid_avg (average of all purchases), Price paid_sum (sum of all purchases), Review (a Boolean variable), Review (out of 10), Total minutes listened, Completion (from 0 to 1), Support requests (number), and Last visited minus purchase date (in days).
#
# So these are the inputs (excluding customer ID, as it is completely arbitrary. It's more like a name, than a number).
#
# The targets are a Boolean variable (so 0, or 1). We are taking a period of 2 years in our inputs, and the next 6 months as targets. So, in fact, we are predicting if: based on the last 2 years of activity and engagement, a customer will convert in the next 6 months. 6 months sounds like a reasonable time. If they don't convert after 6 months, chances are they've gone to a competitor or didn't like the Audiobook way of digesting information.
#
# The task is simple: create a machine learning algorithm, which is able to predict if a customer will buy again.
#
# This is a classification problem with two classes: won't buy and will buy, represented by 0s and 1s.
#
# Good luck!

# %% [markdown]
# ## Create the machine learning algorithm

# %% [markdown]
# ### Import the relevant libraries

# %%
# we must import the libraries once again since we haven't imported them in this file
import numpy as np
import tensorflow as tf

# %% [markdown]
# ### Data

# %%
# let's create a temporary variable npz, where we will store each of the three Audiobooks datasets
npz = np.load('Audiobooks_data_train.npz')

# we extract the inputs using the keyword under which we saved them
# to ensure that they are all floats, let's also take care of that
train_inputs = npz['inputs'].astype(float)
# targets must be int because of sparse_categorical_crossentropy (we want to be able to smoothly one-hot encode them)
train_targets = npz['targets'].astype(int)

# we load the validation data in the temporary variable
npz = np.load('Audiobooks_data_validation.npz')
# we can load the inputs and the targets in the same line
validation_inputs, validation_targets = npz['inputs'].astype(float), npz['targets'].astype(int)

# we load the test data in the temporary variable
npz = np.load('Audiobooks_data_test.npz')
# we create 2 variables that will contain the test inputs and the test targets
test_inputs, test_targets = npz['inputs'].astype(float), npz['targets'].astype(int)

# %% [markdown]
# ### Model
# Outline, optimizers, loss, early stopping and training

# %%
# Set the input and output sizes
input_size = 10
output_size = 2
# Use same hidden layer size for both hidden layers. Not a necessity.
hidden_layer_size = 50
    
# define how the model will look like
model = tf.keras.Sequential([
    # tf.keras.layers.Dense is basically implementing: output = activation(dot(input, weight) + bias)
    # it takes several arguments, but the most important ones for us are the hidden_layer_size and the activation function
    tf.keras.layers.Dense(hidden_layer_size, activation='relu'), # 1st hidden layer
    tf.keras.layers.Dense(hidden_layer_size, activation='relu'), # 2nd hidden layer
    # the final layer is no different, we just make sure to activate it with softmax
    tf.keras.layers.Dense(output_size, activation='softmax') # output layer
])


### Choose the optimizer and the loss function

# we define the optimizer we'd like to use, 
# the loss function, 
# and the metrics we are interested in obtaining at each iteration
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

### Training
# That's where we train the model we have built.

# set the batch size
batch_size = 100

# set a maximum number of training epochs
max_epochs = 100


# fit the model
# note that this time the train, validation and test data are not iterable
model.fit(train_inputs, # train inputs
          train_targets, # train targets
          batch_size=batch_size, # batch size
          epochs=max_epochs, # epochs that we will train for (assuming early stopping doesn't kick in)
          validation_data=(validation_inputs, validation_targets), # validation data
          verbose = 2 # making sure we get enough information about the training process
          )
# Out:
# Epoch 1/100
# 36/36 - 2s - 63ms/step - accuracy: 0.6742 - loss: 0.5724 - val_accuracy: 0.7383 - val_loss: 0.5001
# Epoch 2/100
# 36/36 - 0s - 3ms/step - accuracy: 0.7589 - loss: 0.4540 - val_accuracy: 0.7763 - val_loss: 0.4195
# Epoch 3/100
# 36/36 - 0s - 3ms/step - accuracy: 0.7835 - loss: 0.4080 - val_accuracy: 0.7584 - val_loss: 0.3912
# Epoch 4/100
# 36/36 - 0s - 3ms/step - accuracy: 0.7963 - loss: 0.3838 - val_accuracy: 0.8031 - val_loss: 0.3727
# Epoch 5/100
# 36/36 - 0s - 3ms/step - accuracy: 0.7980 - loss: 0.3719 - val_accuracy: 0.8188 - val_loss: 0.3619
# Epoch 6/100
# 36/36 - 0s - 2ms/step - accuracy: 0.7985 - loss: 0.3636 - val_accuracy: 0.8121 - val_loss: 0.3603
# Epoch 7/100
# 36/36 - 0s - 2ms/step - accuracy: 0.8013 - loss: 0.3573 - val_accuracy: 0.8121 - val_loss: 0.3508
# Epoch 8/100
# 36/36 - 0s - 2ms/step - accuracy: 0.8106 - loss: 0.3483 - val_accuracy: 0.8166 - val_loss: 0.3515
# Epoch 9/100
# 36/36 - 0s - 4ms/step - accuracy: 0.8128 - loss: 0.3451 - val_accuracy: 0.8277 - val_loss: 0.3426
# Epoch 10/100
# 36/36 - 0s - 3ms/step - accuracy: 0.8173 - loss: 0.3414 - val_accuracy: 0.8300 - val_loss: 0.3431
# Epoch 11/100
# 36/36 - 0s - 2ms/step - accuracy: 0.8170 - loss: 0.3387 - val_accuracy: 0.8054 - val_loss: 0.3385
# Epoch 12/100
# 36/36 - 0s - 2ms/step - accuracy: 0.8159 - loss: 0.3391 - val_accuracy: 0.8166 - val_loss: 0.3400
# Epoch 13/100
# 36/36 - 0s - 2ms/step - accuracy: 0.8178 - loss: 0.3354 - val_accuracy: 0.8121 - val_loss: 0.3338
# Epoch 14/100
# 36/36 - 0s - 2ms/step - accuracy: 0.8181 - loss: 0.3316 - val_accuracy: 0.8255 - val_loss: 0.3285
# Epoch 15/100
# 36/36 - 0s - 2ms/step - accuracy: 0.8254 - loss: 0.3294 - val_accuracy: 0.8300 - val_loss: 0.3345
# Epoch 16/100
# 36/36 - 0s - 2ms/step - accuracy: 0.8198 - loss: 0.3309 - val_accuracy: 0.8367 - val_loss: 0.3300
# Epoch 17/100
# 36/36 - 0s - 2ms/step - accuracy: 0.8229 - loss: 0.3269 - val_accuracy: 0.8322 - val_loss: 0.3364
# Epoch 18/100
# 36/36 - 0s - 2ms/step - accuracy: 0.8273 - loss: 0.3246 - val_accuracy: 0.8345 - val_loss: 0.3332
# Epoch 19/100
# 36/36 - 0s - 2ms/step - accuracy: 0.8100 - loss: 0.3301 - val_accuracy: 0.8188 - val_loss: 0.3353
# Epoch 20/100
# 36/36 - 0s - 4ms/step - accuracy: 0.8212 - loss: 0.3242 - val_accuracy: 0.8367 - val_loss: 0.3284
# Epoch 21/100
# 36/36 - 0s - 2ms/step - accuracy: 0.8256 - loss: 0.3221 - val_accuracy: 0.8345 - val_loss: 0.3363
# Epoch 22/100
# 36/36 - 0s - 2ms/step - accuracy: 0.8256 - loss: 0.3215 - val_accuracy: 0.8367 - val_loss: 0.3383
# Epoch 23/100
# 36/36 - 0s - 2ms/step - accuracy: 0.8220 - loss: 0.3233 - val_accuracy: 0.8412 - val_loss: 0.3284
# Epoch 24/100
# 36/36 - 0s - 2ms/step - accuracy: 0.8245 - loss: 0.3207 - val_accuracy: 0.8255 - val_loss: 0.3478
# Epoch 25/100
# 36/36 - 0s - 2ms/step - accuracy: 0.8251 - loss: 0.3202 - val_accuracy: 0.8277 - val_loss: 0.3281
# Epoch 26/100
# 36/36 - 0s - 2ms/step - accuracy: 0.8223 - loss: 0.3210 - val_accuracy: 0.8300 - val_loss: 0.3392
# Epoch 27/100
# 36/36 - 0s - 2ms/step - accuracy: 0.8296 - loss: 0.3167 - val_accuracy: 0.8389 - val_loss: 0.3299
# Epoch 28/100
# 36/36 - 0s - 2ms/step - accuracy: 0.8192 - loss: 0.3195 - val_accuracy: 0.8389 - val_loss: 0.3266
# Epoch 29/100
# 36/36 - 0s - 2ms/step - accuracy: 0.8231 - loss: 0.3190 - val_accuracy: 0.8456 - val_loss: 0.3255
# Epoch 30/100
# 36/36 - 0s - 2ms/step - accuracy: 0.8256 - loss: 0.3174 - val_accuracy: 0.8322 - val_loss: 0.3288
# Epoch 31/100
# 36/36 - 0s - 2ms/step - accuracy: 0.8287 - loss: 0.3177 - val_accuracy: 0.8456 - val_loss: 0.3233
# Epoch 32/100
# 36/36 - 0s - 2ms/step - accuracy: 0.